# %% [markdown]
# <a href="https://colab.research.google.com/github/thrivenid88/DataScience-2023/blob/main/car%20june6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
# There are some fake data csv files
# you can read in as dataframes
df1 = pd.read_csv('/content/drive/MyDrive/cars.csv', index_col=0)
df2 = pd.read_csv('/content/drive/MyDrive/bank.csv')

# %%
df1
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
df1['disp'].hist()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
df1['cyl'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('bmh')
df1['disp'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('fivethirtyeight')
df1['wt'].hist()
# Out:
# <Axes: >

# %%
df2.plot.area(alpha=0.4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-3f8801bd69f6> in <cell line: 1>()
# ----> 1 df2.plot.area(alpha=0.4)
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in area(self, x, y, **kwargs)
#    1555             >>> ax = df.plot.area(x='day')
#    1556         """
# -> 1557         return self(kind="area", x=x, y=y, **kwargs)
#    1558
#    1559     def pie(self, **kwargs) -> PlotAccessor:
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
# ...

# %%
df2.head()
# Out:
#    age         job  marital  education fault  balance housing loan  contact  \
# 0   59      admin.  married  secondary    no     2343     yes   no  unknown
# 1   56      admin.  married  secondary    no       45      no   no  unknown
# 2   41  technician  married  secondary    no     1270     yes   no  unknown
# 3   55    services  married  secondary    no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary    no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df1['disp'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot.line(x=df1.index, y='hp', figsize=(12, 3), lw=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-d526b26ad82b> in <cell line: 1>()
# ----> 1 df1.plot.line(x=df1.index, y='hp', figsize=(12, 3), lw=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in line(self, x, y, **kwargs)
#    1067         as coordinates.
#    1068         """
# -> 1069         return self(kind="line", x=x, y=y, **kwargs)
#    1070
#    1071     @Appender(
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     963                 if is_integer(x) and not data.columns.holds_integer():
#     964                     x = data_cols[x]
# --> 965                 elif not isinstance(data[x], ABCSeries):
#     966                     raise ValueError("x must be a label or position")
#     967                 data = data.set_index(x)
#
# ...

# %%
df1.plot.scatter(x='disp', y='hp')
# Out:
# <Axes: xlabel='disp', ylabel='hp'>
