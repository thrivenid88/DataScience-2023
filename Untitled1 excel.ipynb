# %% [markdown]
# <a href="https://colab.research.google.com/github/thrivenid88/DataScience-2023/blob/main/Untitled1%20excel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas 
import pandas as pd
from pandas import DataFrame

# %%
import pandas as pd
bank=pd.read_excel('/content/drive/MyDrive/Book1.xlsx')
bank.head()
# Out:
#    age         job  marital  education fault  balance housing loan  contact  \
# 0   59      admin.  married  secondary    no     2343     yes   no  unknown
# 1   56      admin.  married  secondary    no       45      no   no  unknown
# 2   41  technician  married  secondary    no     1270     yes   no  unknown
# 3   55    services  married  secondary    no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary    no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
bank.shape
# Out:
# (83, 17)

# %%
bank.info
# Out:
# <bound method DataFrame.info of     age          job   marital  education fault  balance housing loan  \
# 0    59       admin.   married  secondary    no     2343     yes   no
# 1    56       admin.   married  secondary    no       45      no   no
# 2    41   technician   married  secondary    no     1270     yes   no
# 3    55     services   married  secondary    no     2476     yes   no
# 4    54       admin.   married   tertiary    no      184      no   no
# ..  ...          ...       ...        ...   ...      ...     ...  ...
# 78   26  blue-collar   married  secondary    no      246     yes   no
# 79   31  blue-collar   married  secondary    no       92     yes   no
# 80   29       admin.    single  secondary    no      163     yes  yes
# 81   37     services  divorced  secondary    no       49     yes   no
# 82   33  blue-collar    single  secondary    no     -416     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome deposit
# ...

# %%
bank['day'].astype('category')
# Out:
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 78    16
# 79    16
# 80    16
# 81    16
# 82    16
# Name: day, Length: 83, dtype: category
# Categories (10, int64): [5, 6, 7, 8, ..., 13, 14, 15, 16]

# %%
bank['day']=bank['day'].astype('category')
bank['age']=bank['age'].astype('category')

# %%
bank.describe(include='category')
# Out:
#         age  day
# count    83   83
# unique   31   10
# top      41   14
# freq      9   15

# %%
for col in['job','marital']:
  bank[col]=bank[col].astype('category')
  bank.info()
  bank['duration'].mean()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        83 non-null     category
#  1   job        83 non-null     category
#  2   marital    83 non-null     object
#  3   education  83 non-null     object
#  4   fault      83 non-null     object
#  5   balance    83 non-null     int64
#  6   housing    83 non-null     object
#  7   loan       83 non-null     object
#  8   contact    83 non-null     object
#  9   day        83 non-null     category
#  10  month      83 non-null     object
#  11  duration   83 non-null     int64
#  12  campaign   83 non-null     int64
#  13  pdays      83 non-null     int64
#  14  previous   83 non-null     int64
#  15  poutcome   83 non-null     object
#  16  deposit    83 non-null     object
# dtypes: category(3), int64(5), object(9)
# memory usage: 11.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
balance=bank['balance']
balance.min(),balance.mean(),balance.median(),balance.max()
# Out:
# (-416, 1089.6746987951808, 320.0, 10576)

# %%
bank.describe()
# Out:
#             balance     duration   campaign  pdays  previous
# count     83.000000    83.000000  83.000000   83.0      83.0
# mean    1089.674699   921.469880   1.807229   -1.0       0.0
# std     1791.012979   362.001258   1.005568    0.0       0.0
# min     -416.000000   395.000000   1.000000   -1.0       0.0
# 25%       52.000000   653.500000   1.000000   -1.0       0.0
# 50%      320.000000   858.000000   2.000000   -1.0       0.0
# 75%     1482.000000  1119.500000   2.000000   -1.0       0.0
# max    10576.000000  2087.000000   6.000000   -1.0       0.0

# %%
import seaborn as sns
sns.histplot(x=bank['balance'],bins=10,kde=False,color='green');

# %%
import pandas as pd
bank=pd.read_excel('/content/drive/MyDrive/Book1.xlsx')
bank['education']=='secondary'
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
#       ...
# 78     True
# 79     True
# 80     True
# 81     True
# 82     True
# Name: education, Length: 83, dtype: bool

# %%
bank[bank['education']=='secondary']
# Out:
#     age          job   marital  education fault  balance housing loan  \
# 0    59       admin.   married  secondary    no     2343     yes   no
# 1    56       admin.   married  secondary    no       45      no   no
# 2    41   technician   married  secondary    no     1270     yes   no
# 3    55     services   married  secondary    no     2476     yes   no
# 7    60      retired  divorced  secondary    no      545     yes   no
# 8    37   technician   married  secondary    no        1     yes   no
# 9    28     services    single  secondary    no     5090     yes   no
# 10   38       admin.    single  secondary    no      100     yes   no
# 11   30  blue-collar   married  secondary    no      309     yes   no
# 17   49     services   married  secondary    no       -8     yes   no
# 18   41       admin.   married  secondary    no       55     yes   no
# 19   49       admin.  divorced  secondary    no      168     yes  yes
# ...

# %%
maritalstatus=bank[bank['marital']=='single']
print(maritalstatus)
type(maritalstatus)
# Out:
#     age            job marital  education fault  balance housing loan  \
# 5    42     management  single   tertiary    no        0     yes  yes
# 9    28       services  single  secondary    no     5090     yes   no
# 10   38         admin.  single  secondary    no      100     yes   no
# 13   46    blue-collar  single   tertiary    no      460     yes   no
# 14   31     technician  single   tertiary    no      703     yes   no
# 16   32    blue-collar  single    primary    no      611     yes   no
# 21   43     management  single   tertiary    no     2067     yes   no
# 24   37     unemployed  single  secondary    no      381     yes   no
# 25   35    blue-collar  single  secondary    no       40     yes   no
# 26   31     technician  single   tertiary    no       22     yes   no
# 27   43    blue-collar  single  secondary    no        3     yes   no
# 29   28    blue-collar  single  secondary    no      759     yes   no
# ...

# %%
maritalstatus['age'].mean()
# Out:
# 35.95652173913044

# %%
round(maritalstatus['balance'].mean(),2)
# Out:
# 771.83

# %%
(bank['education']=='age')&(bank['housing']==1).shape
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 78    False
# 79    False
# 80    False
# 81    False
# 82    False
# Name: education, Length: 83, dtype: bool

# %%
bank[bank['balance']<=100]
# Out:
#     age           job   marital  education fault  balance housing loan  \
# 1    56        admin.   married  secondary    no       45      no   no
# 5    42    management    single   tertiary    no        0     yes  yes
# 8    37    technician   married  secondary    no        1     yes   no
# 10   38        admin.    single  secondary    no      100     yes   no
# 17   49      services   married  secondary    no       -8     yes   no
# 18   41        admin.   married  secondary    no       55     yes   no
# 23   43   blue-collar   married    primary    no     -192     yes   no
# 25   35   blue-collar    single  secondary    no       40     yes   no
# 26   31    technician    single   tertiary    no       22     yes   no
# 27   43   blue-collar    single  secondary    no        3     yes   no
# 30   32   blue-collar   married  secondary   yes       -1     yes   no
# 31   60    technician   married    primary    no       65     yes   no
# ...

# %%
mgmt=[4,5,6]
bank[bank['balance'].isin(mgmt)]
# Out:
#     age           job   marital  education fault  balance housing loan  \
# 37   33    management  divorced  secondary    no        5     yes   no
# 39   23  entrepreneur    single    primary    no        4     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome deposit
# 37  unknown   13   may      1346         1     -1         0  unknown     yes
# 39  unknown   13   may       395         2     -1         0  unknown     yes

# %%
sum=(balance)
no=(balance)
mean=sum/no
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-f607a3b75b65> in <cell line: 2>()
#       1 sum=len(balance)
# ----> 2 no=sum(balance)
#       3 mean=sum/no
#
# TypeError: 'int' object is not callable
