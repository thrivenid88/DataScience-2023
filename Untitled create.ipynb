# %% [markdown]
# <a href="https://colab.research.google.com/github/thrivenid88/DataScience-2023/blob/main/Untitled%20create.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
std=pd.read_csv("/content/drive/MyDrive/datascience.csv")

# %%
std.head()
# Out:
#    S.no  Roll no.    Name Class  Rg.no            Subject  Marks Obtained
# 0     1        21    JIYA   MSC  FZ0031         CHEMISTRY              87
# 1     2        22    APPU   MSC  FZ0032         CHEMISTRY              89
# 2     3        23  MANAVI   MSC  FZ0033  COMPUTER SCIENCE              90
# 3     4        24   POOJA   MSC  FZ0034  COMPUTER SCIENCE              91
# 4     5        25   VEENA   MSC  FZ0035  COMPUTER SCIENCE              77

# %%
std.tail()
# Out:
#     S.no  Roll no.      Name Class  Rg.no            Subject  Marks Obtained
# 10    11        31  SIDDARTH   MSC  FZ0041  COMPUTER SCIENCE              79
# 11    12        32     NETRA   MSC  FZ0042  COMPUTER SCIENCE              88
# 12    13        33   GOWTHAM   MSC  FZ0043  COMPUTER SCIENCE              92
# 13    14        34    SNDHYA   MSC  FZ0044  COMPUTER SCIENCE              74
# 14    15        35    SONITH   MSC  FZ0045  COMPUTER SCIENCE              77

# %%
std.describe(include='all')
# Out:
#              S.no   Roll no.  Name Class  Rg.no            Subject  \
# count   15.000000  15.000000    15    15      15                15
# unique        NaN        NaN    15     1      15                 4
# top           NaN        NaN  JIYA   MSC  FZ0031  COMPUTER SCIENCE
# freq          NaN        NaN     1    15       1                11
# mean     8.000000  28.000000   NaN   NaN     NaN               NaN
# std      4.472136   4.472136   NaN   NaN     NaN               NaN
# min      1.000000  21.000000   NaN   NaN     NaN               NaN
# 25%      4.500000  24.500000   NaN   NaN     NaN               NaN
# 50%      8.000000  28.000000   NaN   NaN     NaN               NaN
# 75%     11.500000  31.500000   NaN   NaN     NaN               NaN
# max     15.000000  35.000000   NaN   NaN     NaN               NaN
#
#         Marks Obtained
# count        15.000000
# unique             NaN
# top                NaN
# freq               NaN
# mean         82.800000
# ...

# %%
import pandas as pd
import numpy as np
std = pd.read_csv('/content/drive/MyDrive/datascience.csv')
std.insert(3, "column1", np.nan)
print(std.head)
# Out:
# <bound method NDFrame.head of     S.no  Roll no.      Name  column1 Class  Rg.no            Subject  \
# 0      1        21      JIYA      NaN   MSC  FZ0031         CHEMISTRY
# 1      2        22      APPU      NaN   MSC  FZ0032         CHEMISTRY
# 2      3        23    MANAVI      NaN   MSC  FZ0033  COMPUTER SCIENCE
# 3      4        24     POOJA      NaN   MSC  FZ0034  COMPUTER SCIENCE
# 4      5        25     VEENA      NaN   MSC  FZ0035  COMPUTER SCIENCE
# 5      6        26    RAKSHA      NaN   MSC  FZ0036  COMPUTER SCIENCE
# 6      7        27  VINEETHA      NaN   MSC  FZ0037           PHYSICS
# 7      8        28     KAVYA      NaN   MSC  FZ0038             MATHS
# 8      9        29  DHANWIKA      NaN   MSC  FZ0039  COMPUTER SCIENCE
# 9     10        30  SUSHANTH      NaN   MSC  FZ0040  COMPUTER SCIENCE
# 10    11        31  SIDDARTH      NaN   MSC  FZ0041  COMPUTER SCIENCE
# 11    12        32     NETRA      NaN   MSC  FZ0042  COMPUTER SCIENCE
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
 
# Read CSV into pandas
data = pd.read_csv("/content/drive/MyDrive/datascience.csv")
data.head()
df = pd.DataFrame(data)
 
name = df['Subject'].head(12)
price = df['Marks Obtained'].head(12)
 
# Figure Size
fig = plt.figure(figsize =(10, 7))
 # Horizontal Bar Plot
plt.bar(name[0:10], price[0:10])
# Show Plot
plt.show()

# %%
df['Name']
# Out:
# 0         JIYA
# 1         APPU
# 2       MANAVI
# 3        POOJA
# 4        VEENA
# 5       RAKSHA
# 6     VINEETHA
# 7        KAVYA
# 8     DHANWIKA
# 9     SUSHANTH
# 10    SIDDARTH
# 11       NETRA
# 12     GOWTHAM
# 13      SNDHYA
# 14      SONITH
# Name: Name, dtype: object

# %%
std.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'S.no'}>,
#         <Axes: title={'center': 'Roll no.'}>],
#        [<Axes: title={'center': 'column1'}>,
#         <Axes: title={'center': 'Marks Obtained'}>]], dtype=object)

# %%
std.count()
# Out:
# S.no              15
# Roll no.          15
# Name              15
# column1            0
# Class             15
# Rg.no             15
# Subject           15
# Marks Obtained    15
# dtype: int64
