# %% [markdown]
# <a href="https://colab.research.google.com/github/thrivenid88/DataScience-2023/blob/main/audio_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://pypi.python.org/pypi/pydot
# !apt-get -qq install -y graphviz && pip install pydub
import pydub

# %%
# import required libraries
from pydub import AudioSegment
from pydub.playback import play

# Import an audio file
# Format parameter only
# for readability
wav_file = AudioSegment.from_file(file = "/content/drive/MyDrive/file_example_WAV_2MG (2).wav",format = "wav")

# Play the audio file
play(wav_file)
wav_file
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>
